# %% [markdown]
# # Halo saya baru belajar pakai IPYNB
#
# ## Halo maksudnya IPYNB adalah Interactive PYthon NoteBook

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6
#
# Biasanya kita tulis komentar kita itu di sini
#
# > Ini bagian blockquote
#
# **Ini di bold**
#
# _Ini italic_
#
# `ini pake backtick, kita lihat hasilnya apa`
#
# ` = backtick
#
# ~ = tilde

# %% [markdown]
# ![image.png](image.png)

# %%
print("Halo Dunia")
# Out:
# Halo Dunia

# %%
print("Hello World")
# Out:
# Hello World

# %%
suatu_variabel = "Kosong adalah isi"

suatu_variabel
# Out:
# 'Kosong adalah isi'
